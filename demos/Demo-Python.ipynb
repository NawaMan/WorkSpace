# %%
x = 10
print(x + 1)
# Out:
# 11

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
# !which python
# Out:
# /opt/venvs/py3.12.12/bin/python

# %%
import sys, platform
print("Version string:", sys.version)           # full build info
print("Short version:", platform.python_version())
print("Executable:", sys.executable)            # e.g. /opt/python/bin/python
# Out:
# Version string: 3.12.12 (main, Dec  9 2025, 19:02:36) [Clang 21.1.4 ]
# Short version: 3.12.12
# Executable: /opt/venvs/py3.12.12/bin/python
